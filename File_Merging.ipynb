# %%
import pandas as pd

# %%
JanData = pd.read_csv("./Data/Jan_2019_Citibike.csv")
JanData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# 0    Essex Light Rail             40.712774             -74.036486   29612
# 1       Washington St             40.724294             -74.035483   29213
# 2  Liberty Light Rail             40.711242             -74.055701   26164
# 3       Washington St             40.724294             -74.035483   29672
# 4       Washington St             40.724294             -74.035483   29522
#
#      usertype  birth year  gender
# 0  Subscriber        1993       1
# 1  Subscriber        1972       2
# 2  Subscriber        1985       1
# 3    Customer        1969       0
# 4    Customer        1969       0

# %%
FebData = pd.read_csv("./Data/Feb_2019_Citibike.csv")
FebData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           142   35:02.1  37:24.1              3183     Exchange Place
# 1           223   00:46.9  04:30.5              3183     Exchange Place
# 2           106   08:01.3  09:47.4              3183     Exchange Place
# 3           370   09:31.2  15:41.7              3183     Exchange Place
# 4           315   19:53.2  25:09.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3681
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3211
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0       Harborside             40.719252             -74.034234   29677
# 1         Grand St             40.715178             -74.037683   26234
# 2      Paulus Hook             40.714145             -74.033552   29588
# 3       Newark Ave             40.721525             -74.046305   29250
# 4     Manila & 1st             40.721651             -74.042884   29586
#
#      usertype  birth year  gender
# 0  Subscriber        1963       1
# 1  Subscriber        1992       2
# 2  Subscriber        1960       1
# 3  Subscriber        1976       1
# 4  Subscriber        1980       1

# %%
MarData = pd.read_csv("./Data/Mar_2019_Citibike.csv")
MarData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           306   47:08.2  52:14.7              3183     Exchange Place
# 1           123   30:53.0  32:56.8              3183     Exchange Place
# 2           328   18:30.4  23:59.1              3183     Exchange Place
# 3            95   04:47.2  06:22.8              3183     Exchange Place
# 4           169   51:29.4  54:19.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3213
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0     Morris Canal             40.712419             -74.038526   26272
# 1      Paulus Hook             40.714145             -74.033552   26192
# 2   Van Vorst Park             40.718489             -74.047727   26226
# 3      Paulus Hook             40.714145             -74.033552   26204
# 4       Harborside             40.719252             -74.034234   29449
#
#      usertype  birth year  gender
# 0  Subscriber        1989       1
# 1  Subscriber        1966       1
# 2  Subscriber        1971       2
# 3  Subscriber        1985       1
# 4  Subscriber        1971       1

# %%
AprData = pd.read_csv("./Data/Apr_2019_Citibike.csv")
AprData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           107   48:04.8  49:52.4              3183     Exchange Place
# 1           493   41:09.7  49:23.0              3183     Exchange Place
# 2           512   27:07.9  35:40.9              3183     Exchange Place
# 3           196   07:38.2  10:54.6              3183     Exchange Place
# 4           463   19:24.7  27:08.6              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3184
# 1               40.716247               -74.033459            3187
# 2               40.716247               -74.033459            3202
# 3               40.716247               -74.033459            3214
# 4               40.716247               -74.033459            3273
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0       Paulus Hook             40.714145             -74.033552   29536
# 1         Warren St             40.721124             -74.038051   26191
# 2      Newport PATH             40.727224             -74.033759   29302
# 3  Essex Light Rail             40.712774             -74.036486   26220
# 4      Manila & 1st             40.721651             -74.042884   26228
#
#      usertype  birth year  gender
# 0  Subscriber        1966       1
# 1    Customer        1990       1
# 2  Subscriber        1987       2
# 3  Subscriber        1989       1
# 4  Subscriber        1995       1

# %%
MayData = pd.read_csv("./Data/May_2019_Citibike.csv")
MayData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           311   07:36.5  12:47.6              3185          City Hall
# 1           538   08:29.3  17:27.9              3681           Grand St
# 2           178   39:36.5  42:35.0              3638      Washington St
# 3           317   24:28.0  29:45.6              3206            Hilltop
# 4           354   54:39.7  00:34.2              3639         Harborside
#
#    start station latitude  start station longitude  end station id  \
# 0               40.717733               -74.043845            3279
# 1               40.715178               -74.037683            3203
# 2               40.724294               -74.035483            3639
# 3               40.731169               -74.057574            3212
# 4               40.719252               -74.034234            3202
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0      Dixon Mills             40.721630             -74.049968   29224
# 1    Hamilton Park             40.727596             -74.044247   26170
# 2       Harborside             40.719252             -74.034234   29517
# 3  Christ Hospital             40.734786             -74.050444   29606
# 4     Newport PATH             40.727224             -74.033759   26224
#
#      usertype  birth year  gender
# 0  Subscriber        1988       1
# 1  Subscriber        1974       1
# 2  Subscriber        1988       1
# 3  Subscriber        1986       2
# 4    Customer        1986       2

# %%
JunData = pd.read_csv("./Data/Jun_2019_Citibike.csv")
JunData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           316   05:55.7  11:12.0              3187          Warren St
# 1           280   08:09.1  12:50.1              3185          City Hall
# 2          2162   13:11.9  49:14.4              3199       Newport Pkwy
# 3          2184   13:30.1  49:54.2              3199       Newport Pkwy
# 4           139   13:31.9  15:51.8              3207        Oakland Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.721124               -74.038051            3199
# 1               40.717733               -74.043845            3267
# 2               40.728745               -74.032108            3199
# 3               40.728745               -74.032108            3199
# 4               40.737604               -74.052478            3207
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0     Newport Pkwy             40.728745             -74.032108   29677
# 1     Morris Canal             40.712419             -74.038526   29571
# 2     Newport Pkwy             40.728745             -74.032108   26208
# 3     Newport Pkwy             40.728745             -74.032108   29487
# 4      Oakland Ave             40.737604             -74.052478   29592
#
#      usertype  birth year  gender
# 0  Subscriber        1993       1
# 1  Subscriber        1984       1
# 2    Customer        1969       0
# 3    Customer        1969       0
# 4  Subscriber        1994       1

# %%
JanFebData = pd.merge(JanData, FebData, on='tripduration', how= 'inner')
JanFebData.head()
# Out:
#    tripduration starttime_x stoptime_x  start station id_x  \
# 0           201     09:09.7    12:30.9                3183
# 1           201     09:09.7    12:30.9                3183
# 2           201     09:09.7    12:30.9                3183
# 3           201     09:09.7    12:30.9                3183
# 4           201     09:09.7    12:30.9                3183
#
#   start station name_x  start station latitude_x  start station longitude_x  \
# 0       Exchange Place                 40.716247                 -74.033459
# 1       Exchange Place                 40.716247                 -74.033459
# 2       Exchange Place                 40.716247                 -74.033459
# 3       Exchange Place                 40.716247                 -74.033459
# 4       Exchange Place                 40.716247                 -74.033459
#
#    end station id_x end station name_x  end station latitude_x    ...     \
# 0              3214   Essex Light Rail               40.712774    ...
# 1              3214   Essex Light Rail               40.712774    ...
# 2              3214   Essex Light Rail               40.712774    ...
# 3              3214   Essex Light Rail               40.712774    ...
# 4              3214   Essex Light Rail               40.712774    ...
#
#    start station latitude_y  start station longitude_y end station id_y  \
# 0                 40.716247                 -74.033459             3186
# 1                 40.716247                 -74.033459             3481
# 2                 40.716247                 -74.033459             3681
# 3                 40.716247                 -74.033459             3214
# 4                 40.716247                 -74.033459             3275
#
#    end station name_y  end station latitude_y end station longitude_y  \
# 0       Grove St PATH               40.719586              -74.043117
# 1             York St               40.716490              -74.041050
# 2            Grand St               40.715178              -74.037683
# 3    Essex Light Rail               40.712774              -74.036486
# 4      Columbus Drive               40.718355              -74.038914
#
#   bikeid_y  usertype_y birth year_y  gender_y
# 0    29555  Subscriber         1976         1
# 1    29592  Subscriber         1987         1
# 2    29252  Subscriber         1983         1
# 3    29610  Subscriber         1969         0
# 4    26174  Subscriber         1978         1
#
# [5 rows x 29 columns]

# %%
MarAprData = pd.merge(MarData, AprData, on='tripduration', how= 'inner')
MarAprData.head()
# Out:
#    tripduration starttime_x stoptime_x  start station id_x  \
# 0           306     47:08.2    52:14.7                3183
# 1           306     47:08.2    52:14.7                3183
# 2           306     47:08.2    52:14.7                3183
# 3           306     47:08.2    52:14.7                3183
# 4           306     47:08.2    52:14.7                3183
#
#   start station name_x  start station latitude_x  start station longitude_x  \
# 0       Exchange Place                 40.716247                 -74.033459
# 1       Exchange Place                 40.716247                 -74.033459
# 2       Exchange Place                 40.716247                 -74.033459
# 3       Exchange Place                 40.716247                 -74.033459
# 4       Exchange Place                 40.716247                 -74.033459
#
#    end station id_x end station name_x  end station latitude_x    ...     \
# 0              3267       Morris Canal               40.712419    ...
# 1              3267       Morris Canal               40.712419    ...
# 2              3267       Morris Canal               40.712419    ...
# 3              3267       Morris Canal               40.712419    ...
# 4              3267       Morris Canal               40.712419    ...
#
#    start station latitude_y  start station longitude_y end station id_y  \
# 0                 40.716247                 -74.033459             3186
# 1                 40.716247                 -74.033459             3187
# 2                 40.714145                 -74.033552             3185
# 3                 40.719586                 -74.043117             3183
# 4                 40.719586                 -74.043117             3205
#
#    end station name_y  end station latitude_y end station longitude_y  \
# 0       Grove St PATH               40.719586              -74.043117
# 1           Warren St               40.721124              -74.038051
# 2           City Hall               40.717733              -74.043845
# 3      Exchange Place               40.716247              -74.033459
# 4   JC Medical Center               40.716540              -74.049638
#
#   bikeid_y  usertype_y birth year_y  gender_y
# 0    29242  Subscriber         1966         1
# 1    29265  Subscriber         1958         1
# 2    29467  Subscriber         1982         1
# 3    29286  Subscriber         1972         1
# 4    26293  Subscriber         1982         1
#
# [5 rows x 29 columns]

# %%
MayJunData = pd.merge(MayData, JunData, on='tripduration', how= 'inner')
MayJunData.head()
# Out:
#    tripduration starttime_x stoptime_x  start station id_x  \
# 0           311     07:36.5    12:47.6                3185
# 1           311     07:36.5    12:47.6                3185
# 2           311     07:36.5    12:47.6                3185
# 3           311     07:36.5    12:47.6                3185
# 4           311     07:36.5    12:47.6                3185
#
#   start station name_x  start station latitude_x  start station longitude_x  \
# 0            City Hall                 40.717733                 -74.043845
# 1            City Hall                 40.717733                 -74.043845
# 2            City Hall                 40.717733                 -74.043845
# 3            City Hall                 40.717733                 -74.043845
# 4            City Hall                 40.717733                 -74.043845
#
#    end station id_x end station name_x  end station latitude_x    ...     \
# 0              3279        Dixon Mills                40.72163    ...
# 1              3279        Dixon Mills                40.72163    ...
# 2              3279        Dixon Mills                40.72163    ...
# 3              3279        Dixon Mills                40.72163    ...
# 4              3279        Dixon Mills                40.72163    ...
#
#    start station latitude_y  start station longitude_y end station id_y  \
# 0                 40.714584                 -74.042817             3186
# 1                 40.714145                 -74.033552             3267
# 2                 40.719586                 -74.043117             3639
# 3                 40.712774                 -74.036486             3185
# 4                 40.714584                 -74.042817             3186
#
#    end station name_y  end station latitude_y end station longitude_y  \
# 0       Grove St PATH               40.719586              -74.043117
# 1        Morris Canal               40.712419              -74.038526
# 2          Harborside               40.719252              -74.034234
# 3           City Hall               40.717733              -74.043845
# 4       Grove St PATH               40.719586              -74.043117
#
#   bikeid_y  usertype_y birth year_y  gender_y
# 0    29483  Subscriber         1991         2
# 1    29200  Subscriber         1977         2
# 2    29644  Subscriber         1992         2
# 3    29598  Subscriber         1981         2
# 4    26234  Subscriber         1983         2
#
# [5 rows x 29 columns]

# %%
Jan_MarData = pd.merge(JanFebData, MarData, on='tripduration', how= 'inner')
Jan_MarData.head()
# Out:
#    tripduration starttime_x stoptime_x  start station id_x  \
# 0           201     09:09.7    12:30.9                3183
# 1           201     09:09.7    12:30.9                3183
# 2           201     09:09.7    12:30.9                3183
# 3           201     09:09.7    12:30.9                3183
# 4           201     09:09.7    12:30.9                3183
#
#   start station name_x  start station latitude_x  start station longitude_x  \
# 0       Exchange Place                 40.716247                 -74.033459
# 1       Exchange Place                 40.716247                 -74.033459
# 2       Exchange Place                 40.716247                 -74.033459
# 3       Exchange Place                 40.716247                 -74.033459
# 4       Exchange Place                 40.716247                 -74.033459
#
#    end station id_x end station name_x  end station latitude_x   ...    \
# 0              3214   Essex Light Rail               40.712774   ...
# 1              3214   Essex Light Rail               40.712774   ...
# 2              3214   Essex Light Rail               40.712774   ...
# 3              3214   Essex Light Rail               40.712774   ...
# 4              3214   Essex Light Rail               40.712774   ...
#
#    start station latitude  start station longitude end station id  \
# 0               40.714145               -74.033552           3267
# 1               40.714145               -74.033552           3481
# 2               40.717733               -74.043845           3187
# 3               40.717733               -74.043845           3483
# 4               40.717733               -74.043845           3211
#
#    end station name  end station latitude end station longitude bikeid  \
# 0      Morris Canal             40.712419            -74.038526  29508
# 1           York St             40.716490            -74.041050  29606
# 2         Warren St             40.721124            -74.038051  29674
# 3     Montgomery St             40.719420            -74.050990  29641
# 4        Newark Ave             40.721525            -74.046305  29201
#
#      usertype birth year  gender
# 0  Subscriber       1981       0
# 1  Subscriber       1949       1
# 2  Subscriber       1988       1
# 3  Subscriber       1982       1
# 4  Subscriber       1992       2
#
# [5 rows x 43 columns]

# %%
Jan_MarData.to_csv("./Data/Jan_MarData.csv")

# %%
Apr_MayData = pd.merge(AprData, MayJunData, on='tripduration', how= 'inner')
Apr_MayData.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           107   48:04.8  49:52.4              3183     Exchange Place
# 1           107   48:04.8  49:52.4              3183     Exchange Place
# 2           107   48:04.8  49:52.4              3183     Exchange Place
# 3           107   48:04.8  49:52.4              3183     Exchange Place
# 4           107   48:04.8  49:52.4              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3184
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3184
#
#   end station name  end station latitude    ...     start station latitude_y  \
# 0      Paulus Hook             40.714145    ...                    40.727224
# 1      Paulus Hook             40.714145    ...                    40.724294
# 2      Paulus Hook             40.714145    ...                    40.719586
# 3      Paulus Hook             40.714145    ...                    40.724294
# 4      Paulus Hook             40.714145    ...                    40.724294
#
#    start station longitude_y end station id_y  end station name_y  \
# 0                 -74.033759             3638       Washington St
# 1                 -74.035483             3202        Newport PATH
# 2                 -74.043117             3185           City Hall
# 3                 -74.035483             3202        Newport PATH
# 4                 -74.035483             3202        Newport PATH
#
#    end station latitude_y end station longitude_y bikeid_y  usertype_y  \
# 0               40.724294              -74.035483    29487  Subscriber
# 1               40.727224              -74.033759    29553  Subscriber
# 2               40.717733              -74.043845    29638  Subscriber
# 3               40.727224              -74.033759    29203  Subscriber
# 4               40.727224              -74.033759    29594  Subscriber
#
#   birth year_y  gender_y
# 0         1975         1
# 1         1984         1
# 2         1983         1
# 3         1991         1
# 4         1983         2
#
# [5 rows x 43 columns]

# %%
Apr_MayData.to_csv("./Data/Apr_MayData.csv")
